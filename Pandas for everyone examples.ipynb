# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv("H:/SCHOOL/2018/SCHOOL PROJECT GRANT/MIA1.csv")
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,10,11,14,15,17,20,22,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           STATION                       STATION_NAME  ELEVATION  LATITUDE  \
# 0      WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 1      WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 2      WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 3      WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 4      WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 5      WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 6      WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# ...

# %%
raw_data=pd.read_csv("H:/SCHOOL/2018/SCHOOL PROJECT GRANT/MIA1.csv")
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8,10,11,14,15,17,20,22,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# After loading the data into the variable raw_data we want to see the shape (or the size of the dataset)
# To perform that we are going to use the dataframe.shape attribute. That attribute returns a tuple with two values: the number of rows and the number of columns in our dataset.

# %%
rows, columns = raw_data.shape
rows, columns
# Out:
# (96731, 90)

# %% [raw]
# After we would like to know the names of the columns in our dataset. When applying the shape attribute, it says we have 90 columns so let's take a look at it using the attribute columns:

# %%
columnlist=raw_data.columns
columnlist
columnlist[0:11]
# Out:
# Index(['STATION', 'STATION_NAME', 'ELEVATION', 'LATITUDE', 'LONGITUDE', 'DATE',
#        'REPORTTPYE', 'HOURLYSKYCONDITIONS', 'HOURLYVISIBILITY',
#        'HOURLYPRSENTWEATHERTYPE', 'HOURLYDRYBULBTEMPF'],
#       dtype='object')

# %% [markdown]
# ### Now that we know the number of columns in the dataset we can go and slice it. The most simple way to do it is
# dataframe['columnname']

# %%
raw_data['STATION']
# Out:
# 0        WBAN:12839
# 1        WBAN:12839
# 2        WBAN:12839
# 3        WBAN:12839
# 4        WBAN:12839
# 5        WBAN:12839
# 6        WBAN:12839
# 7        WBAN:12839
# 8        WBAN:12839
# 9        WBAN:12839
# 10       WBAN:12839
# 11       WBAN:12839
# 12       WBAN:12839
# 13       WBAN:12839
# 14       WBAN:12839
# 15       WBAN:12839
# 16       WBAN:12839
# 17       WBAN:12839
# 18       WBAN:12839
# 19       WBAN:12839
# 20       WBAN:12839
# 21       WBAN:12839
# 22       WBAN:12839
# 23       WBAN:12839
# 24       WBAN:12839
# 25       WBAN:12839
# 26       WBAN:12839
# 27       WBAN:12839
# 28       WBAN:12839
# 29       WBAN:12839
#             ...
# 96701    WBAN:12839
# 96702    WBAN:12839
# 96703    WBAN:12839
# 96704    WBAN:12839
# 96705    WBAN:12839
# 96706    WBAN:12839
# 96707    WBAN:12839
# 96708    WBAN:12839
# 96709    WBAN:12839
# 96710    WBAN:12839
# 96711    WBAN:12839
# 96712    WBAN:12839
# 96713    WBAN:12839
# 96714    WBAN:12839
# ...

# %% [markdown]
# ## If we would like to subset this column we can do the following:
# df['name'][a:b]

# %%
raw_data['STATION'][1:4]
# Out:
# 1    WBAN:12839
# 2    WBAN:12839
# 3    WBAN:12839
# Name: STATION, dtype: object

# %% [markdown]
# ## But we can do the following too: using the .loc and the iloc methods

# %%
# the first one df.loc is used when you want to treat the data columns and rows using names or categories "labels":
# for example:
raw_data.loc[99] #in this case we are retrieving all info of the record because we did not especied the columns
# Out:
# STATION                                                     WBAN:12839
# STATION_NAME                         MIAMI INTERNATIONAL AIRPORT FL US
# ELEVATION                                                          8.8
# LATITUDE                                                       25.7881
# LONGITUDE                                                     -80.3169
# DATE                                                  1981-01-04 23:00
# REPORTTPYE                                                         SAO
# HOURLYSKYCONDITIONS                                                NaN
# HOURLYVISIBILITY                                                  6.96
# HOURLYPRSENTWEATHERTYPE                                            NaN
# HOURLYDRYBULBTEMPF                                                  57
# HOURLYDRYBULBTEMPC                                                13.9
# HOURLYWETBULBTEMPF                                                  51
# ...

# %%
# If we do the following we can get an specific info
raw_data.loc[1,[name for name in raw_data.columns]]
# Out:
# STATION                                                     WBAN:12839
# STATION_NAME                         MIAMI INTERNATIONAL AIRPORT FL US
# ELEVATION                                                          8.8
# LATITUDE                                                       25.7881
# LONGITUDE                                                     -80.3169
# DATE                                                  1981-01-01 02:00
# REPORTTPYE                                                         SAO
# HOURLYSKYCONDITIONS                                                NaN
# HOURLYVISIBILITY                                                  6.96
# HOURLYPRSENTWEATHERTYPE                                            NaN
# HOURLYDRYBULBTEMPF                                                  50
# HOURLYDRYBULBTEMPC                                                10.0
# HOURLYWETBULBTEMPF                                                  48
# ...

# %%
# or we can do the nex example:
subset=raw_data.loc[1:5,[name for name in raw_data.columns[0:11]]]

# %%
# remember that what we have in the list comprehention is a list containing all names from the first column until 
# the tenth one[name for name in raw_data.columns[0:11]]
[name for name in raw_data.columns[0:11]]
# Out:
# ['STATION',
#  'STATION_NAME',
#  'ELEVATION',
#  'LATITUDE',
#  'LONGITUDE',
#  'DATE',
#  'REPORTTPYE',
#  'HOURLYSKYCONDITIONS',
#  'HOURLYVISIBILITY',
#  'HOURLYPRSENTWEATHERTYPE',
#  'HOURLYDRYBULBTEMPF']

# %%
subset.to_csv("H:\PYTHON\JUPYTER\Test.csv")
# Out:
#       STATION                       STATION_NAME  ELEVATION  LATITUDE  \
# 1  WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 2  WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 3  WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 4  WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
# 5  WBAN:12839  MIAMI INTERNATIONAL AIRPORT FL US        8.8   25.7881
#
#    LONGITUDE              DATE REPORTTPYE HOURLYSKYCONDITIONS  \
# 1   -80.3169  1981-01-01 02:00        SAO                 NaN
# 2   -80.3169  1981-01-01 03:00        SAO                 NaN
# 3   -80.3169  1981-01-01 04:00        SAO                 NaN
# 4   -80.3169  1981-01-01 05:00        SAO                 NaN
# 5   -80.3169  1981-01-01 06:00        SAO                 NaN
#
#   HOURLYVISIBILITY HOURLYPRSENTWEATHERTYPE HOURLYDRYBULBTEMPF
# 1             6.96                     NaN                 50
# ...
